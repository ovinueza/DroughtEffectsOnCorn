# %%
import pandas as pd

# %%
df = pd.read_csv("csv_files/Corn_forFuelAlcohol_Usage_National_MillType_2014-2019.csv")
df.head()
# Out:
#   Program  Year Period  Week Ending Geo Level     State  State ANSI  \
# 0  SURVEY  2019    JAN          NaN  NATIONAL  US TOTAL         NaN
# 1  SURVEY  2019    JAN          NaN  NATIONAL  US TOTAL         NaN
# 2  SURVEY  2019    JAN          NaN  NATIONAL  US TOTAL         NaN
# 3  SURVEY  2019    FEB          NaN  NATIONAL  US TOTAL         NaN
# 4  SURVEY  2019    FEB          NaN  NATIONAL  US TOTAL         NaN
#
#    Ag District  Ag District Code  County  ...  Zip Code  Region  \
# 0          NaN               NaN     NaN  ...       NaN     NaN
# 1          NaN               NaN     NaN  ...       NaN     NaN
# 2          NaN               NaN     NaN  ...       NaN     NaN
# 3          NaN               NaN     NaN  ...       NaN     NaN
# 4          NaN               NaN     NaN  ...       NaN     NaN
#
#    watershed_code  Watershed  Commodity  \
# 0               0        NaN       CORN
# 1               0        NaN       CORN
# 2               0        NaN       CORN
# ...

# %%
df = df[["Period","Domain Category","Value"]]
df.head()
# Out:
#   Period                      Domain Category        Value
# 0    JAN                        NOT SPECIFIED  444,016,000
# 1    JAN  TYPE OF OPERATION: (DRY MILL PLANT)  405,454,000
# 2    JAN  TYPE OF OPERATION: (WET MILL PLANT)   38,562,000
# 3    FEB                        NOT SPECIFIED  402,894,000
# 4    FEB  TYPE OF OPERATION: (DRY MILL PLANT)  367,273,000

# %%
type(df["Value"][0])
# Out:
# str

# %%
df1['Avg_Annual'] = df1['Avg_Annual'].str.replace(',', '')

# %%
df["Converted_Value"] = df["Value"].apply(lambda x: int(x.replace(',',''))
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-9d36d2c6b2b7> in <module>
# ----> 1 df["Converted_Value"] = df["Value"].apply(lambda x: int(x))
#       2 df.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-25-9d36d2c6b2b7> in <lambda>(x)
# ----> 1 df["Converted_Value"] = df["Value"].apply(lambda x: int(x))
#       2 df.head()
#
# ValueError: invalid literal for int() with base 10: '444,016,000'
