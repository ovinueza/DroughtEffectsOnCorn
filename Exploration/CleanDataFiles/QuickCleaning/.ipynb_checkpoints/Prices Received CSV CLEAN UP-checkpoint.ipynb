# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File Load (CSV)
files_to_load= os.path.join("DroughtData_2010_2019.csv")

# Read (CSV)
data= pd.read_csv(files_to_load)
df= pd.DataFrame(data)

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#        Date StateAbbreviation        None          D0          D1         D2  \
# 0      2019                AK  516,396.68   66,184.79   29,277.83  11,664.38
# 1      2019                AK  516,396.68   66,184.79   29,277.83  11,664.38
# 2      2019                AK  479,134.69  103,446.79   60,337.27  15,413.01
# 3      2019                AK  443,823.87  138,757.60   69,240.83  34,192.52
# 4      2019                AK  413,374.73  169,206.74  103,956.37  39,419.36
# 5      2019                AK  402,551.51  180,029.97  103,956.37  39,419.36
# 6      2019                AK  388,413.49  194,167.99  103,956.37  39,419.36
# 7      2019                AK  388,413.49  194,167.99   65,217.85  26,707.89
# 8      2019                AK  404,160.77  178,420.70   56,082.94  21,944.64
# 9      2019                AK  296,295.86  286,285.61   67,829.87  11,664.38
# 10     2019                AK  176,941.52  405,639.96  142,560.81  33,730.35
# ...

# %%
groupby= df.groupby(["Date","StateAbbreviation","None","D0","D1","D2","D3","D4"]).mean()
reset= groupby.reset_index()
reset
# Out:
#        Date StateAbbreviation        None          D0          D1         D2  \
# 0      2009                AK  417,130.28  165,451.20           0          0
# 1      2009                AL   51,613.84           0           0          0
# 2      2009                AR   53,162.75           0           0          0
# 3      2009                AZ           0  114,034.82  110,881.68  81,172.50
# 4      2009                CA   10,380.50  147,767.56  114,122.22  14,618.26
# 5      2009                CO   72,088.76   32,056.90    7,835.34          0
# 6      2009                CT    4,978.77           0           0          0
# 7      2009                DC       60.21           0           0          0
# 8      2009                DE    2,049.97           0           0          0
# 9      2009                FL   54,753.76    1,760.96           0          0
# 10     2009                GA   58,777.25           0           0          0
# ...

# %%
reset.to_csv(r'CleanDroughtData_2010-2019.csv')
